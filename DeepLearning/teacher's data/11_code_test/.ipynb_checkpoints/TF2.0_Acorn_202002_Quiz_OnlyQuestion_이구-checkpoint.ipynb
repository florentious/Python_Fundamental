# %% [markdown]
# # TF-2.0을 기반으로 Deep Learning Model Test

# %% [markdown]
# * 가이드 라인 : 아래와 같은 결과 들이 나올 수 있도록 해당하는 셀을 만들고, 좋은 성능이 나오는 모델을 찾아보세요!!!

# %% [markdown]
# ### 필요한 패키지 불러오기..

# %%
# 3.4 텐서플로 2.0 버전 선택
try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
import numpy as np
import random
seed = 1234
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# # 문제_1) winequality dataset을 기반으로 좋은 분류 모델을 작성하세요!!!

# %% [markdown]
# * 와인 데이터 불러오기 : red/white

# %%
import pandas as pd
red = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')
print(red.head(2))
print(white.head(2))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6

# %% [markdown]
# * 각기 red =0, white =1 로 변환하기 + type컬럼에 작성하기 --> red set + white set합쳐서 하나의 wine 이라는 데이터 셋 완성!!!

# %%
red['type'] = 0
white['type'] = 1
print(red.head(2))
print(white.head(2))

wine = pd.concat([red, white])
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality  type
# 0      9.4        5     0
# 1      9.8        5     0
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
# 1                 14.0                 132.0    0.994  3.3       0.49
#
#    alcohol  quality  type
# 0      8.8        6     1
# 1      9.5        6     1

# %% [markdown]
# * 정규화 수행 + random하게 train/test로 할 것들에 대한 인덱스 처리

# %%
wine_norm = (wine - wine.min()) / (wine.max() - wine.min())

# %%
import numpy as np
wine_shuffle = wine_norm.sample(frac=1,random_state=1234)
print(wine_shuffle.head(2))
wine_np = wine_shuffle.to_numpy()
print(wine_np[:2])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3543       0.181818          0.166667     0.120482        0.018405   0.036545
# 2252       0.280992          0.140000     0.120482        0.108896   0.061462
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 3543             0.166667              0.352535  0.092346  0.534884
# 2252             0.173611              0.387097  0.167920  0.341085
#
#       sulphates   alcohol   quality  type
# 3543   0.174157  0.434783  0.500000   1.0
# 2252   0.168539  0.217391  0.333333   1.0
# [[0.18181818 0.16666667 0.12048193 0.01840491 0.03654485 0.16666667
#   0.35253456 0.09234625 0.53488372 0.1741573  0.43478261 0.5
#   1.        ]
#  [0.28099174 0.14       0.12048193 0.10889571 0.06146179 0.17361111
#   0.38709677 0.1679198  0.34108527 0.16853933 0.2173913  0.33333333
#   1.        ]]

# %% [markdown]
# * 그 값을 기준으로 80프로는 train으로 남은 20프로는 test로

# %%
train_idx = int(len(wine_np) * 0.8)
train_X, train_Y = wine_np[:train_idx, :-1], wine_np[:train_idx, -1]
test_X, test_Y = wine_np[train_idx:, :-1], wine_np[train_idx:, -1]

# %%
train_X.shape
# Out:
# (5197, 12)

# %%
train_Y.shape
# Out:
# (5197, 2)

# %%
#test_Y => one-hot encoding
train_Y = tf.keras.utils.to_categorical(train_Y, num_classes=2)
test_Y = tf.keras.utils.to_categorical(test_Y, num_classes=2)

# %% [markdown]
# ### 문제 1- 1) 위의 데이터를 바탕으로 아래 주어진 조건의 DNN의 모델을 만들고, 수행하세요!!!
#  - 조건1 : 모델 구조 : 입력 레이어 + 히든1층(노드 24, activation = relu) + 히든 2층(노드 12, activation=relu) + 아웃풋 레이어
#  - 조건2: loss = "categorical_crossentropy", metrics = ["accuracy],optimizer=tf.keras.optimizers.Adam(lr=0.07)를 바탕으로 최적화를 수행하세요..
#  - 조건3 :model.evaluate(test_X, test_Y,verbose=2) 을 수행해서 test_X 에 대한 결과를 나타내세요!!!
#  - 주의 사항 : (단, train_X, test_X)는 그대로 유지를 해야, 다른 분들과 동일한 평가를 수행할 수 있습니다!!
#  - 주의 사항 : DNN을 할 때의 y의 값이 어떻게 되어야 하는지 잘 고민을 해야할 것입니다!!!

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=24, activation='relu', input_shape=(12,)),
    tf.keras.layers.Dense(units=12, activation='relu'),
    
    tf.keras.layers.Dense(units=2, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 24)                312
# _________________________________________________________________
# dense_6 (Dense)              (None, 12)                300
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 26
# =================================================================
# Total params: 638
# Trainable params: 638
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.f
# Epoch 20/20
# 3897/3897 [==============================] - 1s 165us/sample - loss: 0.0313 - accuracy: 0.9920 - val_loss: 0.0249 - val_accuracy: 0.9938

# %%
history = model.fit(train_X, train_Y, epochs=20, batch_size=32, validation_split=0.25)
# Out:
# Train on 3897 samples, validate on 1300 samples
# Epoch 1/20
# 3897/3897 [==============================] - 1s 176us/sample - loss: 0.1285 - accuracy: 0.9523 - val_loss: 0.0468 - val_accuracy: 0.9862
# Epoch 2/20
# 3897/3897 [==============================] - 0s 41us/sample - loss: 0.0651 - accuracy: 0.9815 - val_loss: 0.0516 - val_accuracy: 0.9931
# Epoch 3/20
# 3897/3897 [==============================] - 0s 43us/sample - loss: 0.0593 - accuracy: 0.9831 - val_loss: 0.0643 - val_accuracy: 0.9800
# Epoch 4/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0568 - accuracy: 0.9823 - val_loss: 0.0338 - val_accuracy: 0.9923
# Epoch 5/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0402 - accuracy: 0.9879 - val_loss: 0.0327 - val_accuracy: 0.9908
# Epoch 6/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0379 - accuracy: 0.9887 - val_loss: 0.0328 - val_accuracy: 0.9923
# Epoch 7/20
# 3897/3897 [==============================] - 0s 49us/sample - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.0631 - val_accuracy: 0.9831
# Epoch 8/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0453 - accuracy: 0.9869 - val_loss: 0.0285 - val_accuracy: 0.9923
# Epoch 9/20
# 3897/3897 [==============================] - 0s 46us/sample - loss: 0.0361 - accuracy: 0.9908 - val_loss: 0.0289 - val_accuracy: 0.9923
# Epoch 10/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0310 - accuracy: 0.9933 - val_loss: 0.0324 - val_accuracy: 0.9946
# Epoch 11/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0335 - accuracy: 0.9918 - val_loss: 0.0281 - val_accuracy: 0.9931
# Epoch 12/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0435 - accuracy: 0.9879 - val_loss: 0.0278 - val_accuracy: 0.9931
# Epoch 13/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0345 - accuracy: 0.9910 - val_loss: 0.0256 - val_accuracy: 0.9938
# Epoch 14/20
# 3897/3897 [==============================] - 0s 45us/sample - loss: 0.0297 - accuracy: 0.9923 - val_loss: 0.0389 - val_accuracy: 0.9908
# Epoch 15/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0391 - accuracy: 0.9879 - val_loss: 0.0419 - val_accuracy: 0.9908
# Epoch 16/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0306 - accuracy: 0.9915 - val_loss: 0.0264 - val_accuracy: 0.9938
# Epoch 17/20
# 3897/3897 [==============================] - 0s 48us/sample - loss: 0.0302 - accuracy: 0.9915 - val_loss: 0.0337 - val_accuracy: 0.9908
# Epoch 18/20
# 3897/3897 [==============================] - 0s 48us/sample - loss: 0.0308 - accuracy: 0.9920 - val_loss: 0.0258 - val_accuracy: 0.9946
# Epoch 19/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0252 - accuracy: 0.9938 - val_loss: 0.0251 - val_accuracy: 0.9954
# Epoch 20/20
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0277 - accuracy: 0.9941 - val_loss: 0.0209 - val_accuracy: 0.9954

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

# %%
model.evaluate(test_X, test_Y,verbose=2)
# Out:
# 1300/1 - 0s - loss: 0.0153 - accuracy: 0.9892
# [0.026162641578568863, 0.98923075]

# %%
# 추가 테스트한 결과
model.evaluate(test_X, test_Y,verbose=2)
# Out:
# 1300/1 - 0s - loss: 0.0121 - accuracy: 0.9946
# [0.02275209672247561, 0.9946154]

# %% [markdown]
# ### 문제 1- 2)  위에서 작성한 것보다 보다 좋은 개선된 모델을 만들어 보세요!!![ 목표 : 0.99 accuracy 이상]
#  - 단, DNN 구조의 모델을 기본으로 하고, 다른  ML알고리즘이 아닌  DNN의 구조를 바탕으로 다양한 모델을 만들어서  좋은 모델을 찾아보세요.
#  - model.evaluate(test_X, test_Y,verbose=2) 위와 동일하게 한 결과에 대해서 개선된 부분을 찾아보시길 바랍니다.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=24, activation='relu', input_shape=(12,)),
    tf.keras.layers.Dense(units=12, activation='relu'),
    tf.keras.layers.Dense(units=12, activation='relu')
    
    tf.keras.layers.Dense(units=2, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.07),  loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_X, train_Y, epochs=20, batch_size=32, validation_split=0.25)
model.evaluate(test_X, test_Y,verbose=2)
# Out:
# Train on 3897 samples, validate on 1300 samples
# Epoch 1/20
# 3897/3897 [==============================] - 2s 602us/sample - loss: 0.1142 - accuracy: 0.9625 - val_loss: 0.0808 - val_accuracy: 0.9769
# Epoch 2/20
# 3897/3897 [==============================] - 1s 218us/sample - loss: 0.0792 - accuracy: 0.9754 - val_loss: 0.0880 - val_accuracy: 0.9846
# Epoch 3/20
# 3897/3897 [==============================] - 1s 221us/sample - loss: 0.0869 - accuracy: 0.9749 - val_loss: 0.1194 - val_accuracy: 0.9662
# Epoch 4/20
# 3897/3897 [==============================] - 1s 225us/sample - loss: 0.0720 - accuracy: 0.9790 - val_loss: 0.0427 - val_accuracy: 0.9877
# Epoch 5/20
# 3897/3897 [==============================] - 1s 224us/sample - loss: 0.0469 - accuracy: 0.9877 - val_loss: 0.0323 - val_accuracy: 0.9915
# Epoch 6/20
# 3897/3897 [==============================] - 1s 247us/sample - loss: 0.0363 - accuracy: 0.9910 - val_loss: 0.0298 - val_accuracy: 0.9931
# Epoch 7/20
# 3897/3897 [==============================] - 1s 233us/sample - loss: 0.0438 - accuracy: 0.9874 - val_loss: 0.1144 - val_accuracy: 0.9854
# Epoch 8/20
# 3897/3897 [==============================] - 1s 224us/sample - loss: 0.0917 - accuracy: 0.9766 - val_loss: 0.0357 - val_accuracy: 0.9931
# Epoch 9/20
# 3897/3897 [==============================] - 1s 224us/sample - loss: 0.0423 - accuracy: 0.9895 - val_loss: 0.0323 - val_accuracy: 0.9915
# Epoch 10/20
# 3897/3897 [==============================] - 1s 233us/sample - loss: 0.0438 - accuracy: 0.9887 - val_loss: 0.0340 - val_accuracy: 0.9931
# Epoch 11/20
# 3897/3897 [==============================] - 1s 245us/sample - loss: 0.0390 - accuracy: 0.9900 - val_loss: 0.0514 - val_accuracy: 0.9869
# Epoch 12/20
# 3897/3897 [==============================] - 1s 230us/sample - loss: 0.0399 - accuracy: 0.9897 - val_loss: 0.0318 - val_accuracy: 0.9915
# Epoch 13/20
# 3897/3897 [==============================] - 1s 236us/sample - loss: 0.0383 - accuracy: 0.9902 - val_loss: 0.0297 - val_accuracy: 0.9931
# Epoch 14/20
# 3897/3897 [==============================] - 1s 229us/sample - loss: 0.0432 - accuracy: 0.9882 - val_loss: 0.0608 - val_accuracy: 0.9838
# Epoch 15/20
# 3897/3897 [==============================] - 1s 240us/sample - loss: 0.0339 - accuracy: 0.9918 - val_loss: 0.0299 - val_accuracy: 0.9931
# 3897/3897 [==============================] - 0s 50us/sample - loss: 0.0501 - accuracy: 0.9856 - val_loss: 0.0276 - val_accuracy: 0.9938
# Epoch 16/19
# 3897/3897 [==============================] - 0s 50us/sample - loss: 0.0354 - accuracy: 0.9908 - val_loss: 0.0256 - val_accuracy: 0.9946
# Epoch 17/19
# 3897/3897 [==============================] - 0s 47us/sample - loss: 0.0336 - accuracy: 0.9918 - val_loss: 0.0280 - val_accuracy: 0.9931
# Epoch 18/19
# 3897/3897 [==============================] - 0s 48us/sample - loss: 0.0341 - accuracy: 0.9928 - val_loss: 0.0244 - val_accuracy: 0.9938
# Epoch 19/19
# 3897/3897 [==============================] - 0s 48us/sample - loss: 0.0271 - accuracy: 0.9936 - val_loss: 0.0216 - val_accuracy: 0.9962
# 1300/1 - 0s - loss: 0.0101 - accuracy: 0.9962
# [0.018296551334743318, 0.99615383]

# %% [markdown]
# # 문제_ 2) Fashion_MNIST 데이터를 활용한 CNN모델을 만들기

# %% [markdown]
# * 데이터 불러오기

# %%
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

train_X = train_X / 255.0
test_X = test_X / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# * train_X, test_X의 모양 변경 : 28 by 28 and 1 channel

# %%
train_X = train_X.reshape(-1, 28, 28, 1)
test_X = test_X.reshape(-1, 28, 28, 1)

# %% [markdown]
# * target label 설명
#  - 0 : 티셔츠/상의
#  - 1 : 바지
#  - 2 :스웨터
#  - 3 :드레스
#  - 4 :코트
#  - 5 : 샌들
#  - 6 : 셔츠
#  - 7 : 운동화
#  - 8 : 가방
#  - 9 : 부츠

# %% [markdown]
# * 참고로 실제 데이터 확인

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# 전체 그래프의 사이즈를 width=10, height=10 으로 지정합니다.
plt.figure(figsize=(10, 10))
for c in range(16):
    # 4행 4열로 지정한 grid 에서 c+1 번째의 칸에 그래프를 그립니다. 1~16 번째 칸을 채우게 됩니다.
    plt.subplot(4,4,c+1)
    plt.imshow(train_X[c].reshape(28,28), cmap='gray')
    
plt.show()

# train 데이터의 첫번째 ~ 16번째 까지의 라벨을 프린트합니다.
print(train_Y[:16])
# Out:
# [9 0 0 3 0 2 7 2 5 5 0 9 5 5 7 9]

# %% [markdown]
# ### 문제 2- 1)  CNN 모델을 활용하여 분류 모델을 완성하세요..
#  - 조건 :
#      - 입력 레이어
#      - conv1 layer : 3by3의 커널로 Conv2D, 필터 수 16개
#      - conv2 layer : 3by3 의 커널로 Conv2D, 필터 수 : 32개
#      - Neural Network : node : 128개, activation : relu
#      - 출력 레이터
#      - 컴파일 조건 : loss = "sparse_categorical_crossentropy", metrics=["accuracy"],optimizer=tf.keras.optimizers.Adam()를 기반으로 할 것..
#  - 조건 : model.evaluate(test_X, test_Y, verbose=0)에 대한 출력 확인
#  - 조건 : 학습은 train_X, train_Y 사용

# %%
model = tf.keras.Sequential([
~~~
])

model.compile(optimizer=tf.keras.optimizers.Adam(),  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(~~~)
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/3
# 45000/45000 [==============================] - 149s 3ms/sample - loss: 0.4554 - accuracy: 0.8365 - val_loss: 0.3718 - val_accuracy: 0.8648
# Epoch 2/3
# 45000/45000 [==============================] - 149s 3ms/sample - loss: 0.3213 - accuracy: 0.8827 - val_loss: 0.3402 - val_accuracy: 0.8771
# Epoch 3/3
# 45000/45000 [==============================] - 138s 3ms/sample - loss: 0.2600 - accuracy: 0.9036 - val_loss: 0.3563 - val_accuracy: 0.8727
# [0.3792726293206215, 0.8683]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=16),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=32),
    # 평탄화
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation='relu'),
    tf.keras.layers.Dense(units=10, activation='softmax')
    
    
])

model.compile(optimizer=tf.keras.optimizers.Adam(),  loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_X,train_Y, epochs=10, validation_split=0.25)
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/10
# 45000/45000 [==============================] - 20s 442us/sample - loss: 0.4512 - accuracy: 0.8398 - val_loss: 0.3814 - val_accuracy: 0.8620
# Epoch 2/10
# 45000/45000 [==============================] - 20s 434us/sample - loss: 0.3172 - accuracy: 0.8842 - val_loss: 0.3453 - val_accuracy: 0.8765
# Epoch 3/10
# 45000/45000 [==============================] - 20s 439us/sample - loss: 0.2578 - accuracy: 0.9047 - val_loss: 0.3734 - val_accuracy: 0.8689
# Epoch 4/10
# 45000/45000 [==============================] - 21s 456us/sample - loss: 0.2094 - accuracy: 0.9226 - val_loss: 0.3791 - val_accuracy: 0.8759
# Epoch 5/10
# 45000/45000 [==============================] - 20s 451us/sample - loss: 0.1747 - accuracy: 0.9357 - val_loss: 0.4333 - val_accuracy: 0.8732
# Epoch 6/10
# 45000/45000 [==============================] - 20s 447us/sample - loss: 0.1463 - accuracy: 0.9467 - val_loss: 0.4912 - val_accuracy: 0.8663
# Epoch 7/10
# 45000/45000 [==============================] - 20s 445us/sample - loss: 0.1254 - accuracy: 0.9541 - val_loss: 0.5051 - val_accuracy: 0.8705
# Epoch 8/10
# 45000/45000 [==============================] - 20s 447us/sample - loss: 0.1102 - accuracy: 0.9599 - val_loss: 0.5598 - val_accuracy: 0.8707
# Epoch 9/10
# 45000/45000 [==============================] - 20s 446us/sample - loss: 0.0924 - accuracy: 0.9669 - val_loss: 0.6717 - val_accuracy: 0.8703
# Epoch 10/10
# 45000/45000 [==============================] - 20s 447us/sample - loss: 0.0913 - accuracy: 0.9670 - val_loss: 0.6761 - val_accuracy: 0.8672
# [0.7003964703723788, 0.8653]

# %% [markdown]
# * 위에서 학습한 것을 확인하는 용도 코드

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()

plt.show()

model.evaluate(test_X, test_Y, verbose=0)
# Out:
# [0.3792726293206215, 0.8683]

# %% [markdown]
# ### 문제 2- 2)  위에서 작성한 것보다 보다 좋은 개선된 모델을 만들어 보세요!!! [목표 : accuracy 0.91이상]
#  - 단, CNN 구조의 모델을 기본으로 하고, 위의 것 보다 좋은 모델을 만들어 보세요!!!
#  - 다양한 방식을 활용해서 레이어 구조 변경, 다른 모델 차용 등....
#  - model.evaluate(test_X, test_Y,verbose=0) 위와 동일하게 한 결과에 대해서 개선된 부분을 찾아보시길 바랍니다.

# %%
# 하나의 예시....
model = tf.keras.Sequential([
   ~~~~~~~
])

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(~~~~)
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/10
# 45000/45000 [==============================] - 1063s 24ms/sample - loss: 0.5920 - accuracy: 0.7839 - val_loss: 0.3281 - val_accuracy: 0.8767
# Epoch 2/10
# 45000/45000 [==============================] - 1058s 24ms/sample - loss: 0.3684 - accuracy: 0.8663 - val_loss: 0.2764 - val_accuracy: 0.8945
# Epoch 3/10
# 45000/45000 [==============================] - 1073s 24ms/sample - loss: 0.3258 - accuracy: 0.8840 - val_loss: 0.2542 - val_accuracy: 0.9078
# Epoch 4/10
# 45000/45000 [==============================] - 1055s 23ms/sample - loss: 0.3048 - accuracy: 0.8921 - val_loss: 0.2439 - val_accuracy: 0.9110
# Epoch 5/10
# 45000/45000 [==============================] - 1059s 24ms/sample - loss: 0.2891 - accuracy: 0.8964 - val_loss: 0.2272 - val_accuracy: 0.9148
# Epoch 6/10
# 45000/45000 [==============================] - 1067s 24ms/sample - loss: 0.2771 - accuracy: 0.9018 - val_loss: 0.2410 - val_accuracy: 0.9109
# Epoch 7/10
# 45000/45000 [==============================] - 1059s 24ms/sample - loss: 0.2670 - accuracy: 0.9045 - val_loss: 0.2238 - val_accuracy: 0.9191
# Epoch 8/10
# 45000/45000 [==============================] - 1056s 23ms/sample - loss: 0.2595 - accuracy: 0.9063 - val_loss: 0.2217 - val_accuracy: 0.9170
# Epoch 9/10
# 45000/45000 [==============================] - 1057s 23ms/sample - loss: 0.2595 - accuracy: 0.9068 - val_loss: 0.2221 - val_accuracy: 0.9195
# Epoch 10/10
# 45000/45000 [==============================] - 1056s 23ms/sample - loss: 0.2497 - accuracy: 0.9088 - val_loss: 0.2188 - val_accuracy: 0.9223
# [0.2362356955766678, 0.9152]

# %%
import os
# 파일 이름에 에포크 번호를 포함시킵니다(`str.format` 포맷)
checkpoint_path = "drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, verbose=1, save_weights_only=True)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(),loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_X,train_Y, epochs=30, validation_split=0.25, callbacks = [cp_callback])
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 44864/45000 [============================>.] - ETA: 0s - loss: 0.5065 - accuracy: 0.8173
# Epoch 00001: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0001.ckpt
# 45000/45000 [==============================] - 10s 228us/sample - loss: 0.5059 - accuracy: 0.8175 - val_loss: 0.3045 - val_accuracy: 0.8863
# Epoch 2/30
# 44832/45000 [============================>.] - ETA: 0s - loss: 0.3121 - accuracy: 0.8870
# Epoch 00002: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0002.ckpt
# 45000/45000 [==============================] - 10s 219us/sample - loss: 0.3117 - accuracy: 0.8871 - val_loss: 0.2570 - val_accuracy: 0.9053
# Epoch 3/30
# 44800/45000 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.9039
# Epoch 00003: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0003.ckpt
# 45000/45000 [==============================] - 10s 233us/sample - loss: 0.2693 - accuracy: 0.9040 - val_loss: 0.2481 - val_accuracy: 0.9077
# Epoch 4/30
# 44768/45000 [============================>.] - ETA: 0s - loss: 0.2432 - accuracy: 0.9132
# Epoch 00004: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0004.ckpt
# 45000/45000 [==============================] - 10s 228us/sample - loss: 0.2430 - accuracy: 0.9133 - val_loss: 0.2235 - val_accuracy: 0.9191
# Epoch 5/30
# 44864/45000 [============================>.] - ETA: 0s - loss: 0.2281 - accuracy: 0.9183
# Epoch 00005: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0005.ckpt
# 45000/45000 [==============================] - 10s 223us/sample - loss: 0.2280 - accuracy: 0.9183 - val_loss: 0.2182 - val_accuracy: 0.9230
# Epoch 6/30
# 44832/45000 [============================>.] - ETA: 0s - loss: 0.2151 - accuracy: 0.9227
# Epoch 00006: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0006.ckpt
# 45000/45000 [==============================] - 10s 222us/sample - loss: 0.2152 - accuracy: 0.9227 - val_loss: 0.2024 - val_accuracy: 0.9268
# Epoch 7/30
# 44800/45000 [============================>.] - ETA: 0s - loss: 0.1994 - accuracy: 0.9278
# Epoch 00007: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0007.ckpt
# 45000/45000 [==============================] - 10s 224us/sample - loss: 0.1993 - accuracy: 0.9278 - val_loss: 0.2281 - val_accuracy: 0.9189
# Epoch 8/30
# 44832/45000 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9310
# Epoch 00008: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0008.ckpt
# 45000/45000 [==============================] - 10s 222us/sample - loss: 0.1935 - accuracy: 0.9310 - val_loss: 0.1930 - val_accuracy: 0.9309
# Epoch 9/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1813 - accuracy: 0.9342
# Epoch 00009: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0009.ckpt
# 45000/45000 [==============================] - 10s 227us/sample - loss: 0.1813 - accuracy: 0.9341 - val_loss: 0.1965 - val_accuracy: 0.9313
# Epoch 10/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1752 - accuracy: 0.9382
# Epoch 00010: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0010.ckpt
# 45000/45000 [==============================] - 10s 223us/sample - loss: 0.1751 - accuracy: 0.9382 - val_loss: 0.2068 - val_accuracy: 0.9282
# Epoch 11/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1685 - accuracy: 0.9387
# Epoch 00011: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0011.ckpt
# 45000/45000 [==============================] - 10s 222us/sample - loss: 0.1684 - accuracy: 0.9388 - val_loss: 0.2071 - val_accuracy: 0.9329
# Epoch 12/30
# 44960/45000 [============================>.] - ETA: 0s - loss: 0.1625 - accuracy: 0.9411
# Epoch 00012: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0012.ckpt
# 45000/45000 [==============================] - 10s 221us/sample - loss: 0.1626 - accuracy: 0.9411 - val_loss: 0.1937 - val_accuracy: 0.9317
# Epoch 13/30
# 44992/45000 [============================>.] - ETA: 0s - loss: 0.1584 - accuracy: 0.9425
# Epoch 00013: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0013.ckpt
# 45000/45000 [==============================] - 10s 220us/sample - loss: 0.1584 - accuracy: 0.9425 - val_loss: 0.2225 - val_accuracy: 0.9313
# Epoch 14/30
# 44864/45000 [============================>.] - ETA: 0s - loss: 0.1550 - accuracy: 0.9449
# Epoch 00014: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0014.ckpt
# 45000/45000 [==============================] - 10s 226us/sample - loss: 0.1550 - accuracy: 0.9449 - val_loss: 0.2032 - val_accuracy: 0.9321
# Epoch 15/30
# 44960/45000 [============================>.] - ETA: 0s - loss: 0.1499 - accuracy: 0.9454
# Epoch 00015: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0015.ckpt
# 45000/45000 [==============================] - 10s 225us/sample - loss: 0.1499 - accuracy: 0.9454 - val_loss: 0.2130 - val_accuracy: 0.9305
# Epoch 16/30
# 44864/45000 [============================>.] - ETA: 0s - loss: 0.1480 - accuracy: 0.9465
# Epoch 00016: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0016.ckpt
# 45000/45000 [==============================] - 10s 222us/sample - loss: 0.1479 - accuracy: 0.9465 - val_loss: 0.2309 - val_accuracy: 0.9306
# Epoch 17/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1405 - accuracy: 0.9496
# Epoch 00017: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0017.ckpt
# 45000/45000 [==============================] - 10s 225us/sample - loss: 0.1406 - accuracy: 0.9496 - val_loss: 0.2180 - val_accuracy: 0.9313
# Epoch 18/30
# 44960/45000 [============================>.] - ETA: 0s - loss: 0.1425 - accuracy: 0.9485
# Epoch 00018: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0018.ckpt
# 45000/45000 [==============================] - 10s 224us/sample - loss: 0.1425 - accuracy: 0.9485 - val_loss: 0.2119 - val_accuracy: 0.9351
# Epoch 19/30
# 44864/45000 [============================>.] - ETA: 0s - loss: 0.1333 - accuracy: 0.9513
# Epoch 00019: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0019.ckpt
# 45000/45000 [==============================] - 10s 220us/sample - loss: 0.1333 - accuracy: 0.9513 - val_loss: 0.2191 - val_accuracy: 0.9334
# Epoch 20/30
# 44992/45000 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9537
# Epoch 00020: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0020.ckpt
# 45000/45000 [==============================] - 10s 225us/sample - loss: 0.1298 - accuracy: 0.9537 - val_loss: 0.2204 - val_accuracy: 0.9331
# Epoch 21/30
# 44832/45000 [============================>.] - ETA: 0s - loss: 0.1393 - accuracy: 0.9506
# Epoch 00021: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0021.ckpt
# 45000/45000 [==============================] - 10s 224us/sample - loss: 0.1391 - accuracy: 0.9507 - val_loss: 0.2184 - val_accuracy: 0.9310
# Epoch 22/30
# 44960/45000 [============================>.] - ETA: 0s - loss: 0.1323 - accuracy: 0.9531
# Epoch 00022: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0022.ckpt
# 45000/45000 [==============================] - 10s 221us/sample - loss: 0.1324 - accuracy: 0.9531 - val_loss: 0.2247 - val_accuracy: 0.9315
# Epoch 23/30
# 44736/45000 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9532
# Epoch 00023: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0023.ckpt
# 45000/45000 [==============================] - 10s 222us/sample - loss: 0.1324 - accuracy: 0.9532 - val_loss: 0.2226 - val_accuracy: 0.9309
# Epoch 24/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9552
# Epoch 00024: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0024.ckpt
# 45000/45000 [==============================] - 10s 221us/sample - loss: 0.1274 - accuracy: 0.9551 - val_loss: 0.2261 - val_accuracy: 0.9304
# Epoch 25/30
# 44832/45000 [============================>.] - ETA: 0s - loss: 0.1269 - accuracy: 0.9539
# Epoch 00025: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0025.ckpt
# 45000/45000 [==============================] - 10s 221us/sample - loss: 0.1269 - accuracy: 0.9539 - val_loss: 0.2279 - val_accuracy: 0.9328
# Epoch 26/30
# 44896/45000 [============================>.] - ETA: 0s - loss: 0.1267 - accuracy: 0.9565
# Epoch 00026: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0026.ckpt
# 45000/45000 [==============================] - 10s 227us/sample - loss: 0.1267 - accuracy: 0.9565 - val_loss: 0.2198 - val_accuracy: 0.9330
# Epoch 27/30
# 44800/45000 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9591
# Epoch 00027: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0027.ckpt
# 45000/45000 [==============================] - 10s 224us/sample - loss: 0.1179 - accuracy: 0.9592 - val_loss: 0.2429 - val_accuracy: 0.9329
# Epoch 28/30
# 44928/45000 [============================>.] - ETA: 0s - loss: 0.1238 - accuracy: 0.9570
# Epoch 00028: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0028.ckpt
# 45000/45000 [==============================] - 10s 225us/sample - loss: 0.1238 - accuracy: 0.9570 - val_loss: 0.2460 - val_accuracy: 0.9343
# Epoch 29/30
# 44928/45000 [============================>.] - ETA: 0s - loss: 0.1233 - accuracy: 0.9572
# Epoch 00029: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0029.ckpt
# 45000/45000 [==============================] - 10s 224us/sample - loss: 0.1232 - accuracy: 0.9572 - val_loss: 0.2251 - val_accuracy: 0.9351
# Epoch 30/30
# 44768/45000 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9605
# Epoch 00030: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0030.ckpt
# 45000/45000 [==============================] - 10s 221us/sample - loss: 0.1169 - accuracy: 0.9606 - val_loss: 0.2378 - val_accuracy: 0.9338
# [0.24882967873364686, 0.9288]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(28,28,1), kernel_size=(3,3), filters=32, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=256, padding='valid', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Dense(units=256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.4),
    tf.keras.layers.Dense(units=10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(),loss='sparse_categorical_crossentropy', metrics=['accuracy'])


checkpoint_path_best = 'drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0022.ckpt'
model.load_weights(checkpoint_path_best)
model.evaluate(test_X, test_Y, verbose=0)
# Out:
# [0.25132420434653757, 0.9317]

# %% [markdown]
# # 문제3) 수업 중에 다루었던 Titanic data 을 활용하여 생존 여부를 예측하는 모델을 작성하세요!!!

# %% [markdown]
# * 필요 패키지들

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ### 문제 3-1) 아래의 titanic_train.csv를 불러오고, .head(3)을 통해서 데이터를 확인하세요!!

# %%
df = pd.read_csv('drive/My Drive/pythonWorkspace/HelloTest/titanic_train.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
#
# [3 rows x 12 columns]

# %% [markdown]
# ### 참고 : 데이터 항목 설명
#  - surveved : 생존여부(0/1),
#  - Pclass : 티켓의 클래스(1은 1st, 2는 2nd ..),
#  - n ame : 승객이름,
#  - sex : 승객성별,
#  - Age : 승객나이,
#  - SibSp : 함께 탑승한 형재와 배우자의 수,
#  - parch : 함께 탑승한 부모, 아이의 수,
#  - ticket: 티켓번호,
#  - Fare: 탑승료,
#  - cabin : 객실번호,
#  - embarked :탑승항구(C:Cherboug, Q :Queenstown, S:south ampton)

# %% [markdown]
# #### outlier 제거를 위한 부분 --> 2칼럼 초과하여 3칼럼 모두 이상치인 데이터는 제거를 하기 위한 부분

# %%
from collections import Counter
# by ) Tukey method (Tukey JW., 1977) 을 사용을 하고, 수치 데이터 아웃라이어가 2개 이상 발생 시 해당 데이터를 제거하기 위한 작업 중
def detect_outliers(df, n, features):
    outlier_indices = []
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        # outlier step
        outlier_step = 1.5 * IQR
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        outlier_indices.extend(outlier_list_col)
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)  
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# %%
# detect outliers from Age, SibSp , Parch and Fare
Outliers_to_drop = detect_outliers(df,2,["Age","SibSp","Parch","Fare"])

# %%
df = df.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 12 columns):
# PassengerId    881 non-null int64
# Survived       881 non-null int64
# Pclass         881 non-null int64
# Name           881 non-null object
# Sex            881 non-null object
# Age            711 non-null float64
# SibSp          881 non-null int64
# Parch          881 non-null int64
# Ticket         881 non-null object
# Fare           881 non-null float64
# Cabin          201 non-null object
# Embarked       879 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 82.7+ KB

# %% [markdown]
# * 아래와 같이 빵구난 데이터를 확인하세요!

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            170
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          680
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 문제 3_2) Embarked의 빠진 2개의 데이터를 "S"의 문자열 값으로 채우세요!! --> 그리고 제대로 채워졌는지 확인하세요!!!

# %%
########## 수정한 코드

df["Embarked"] = df.Embarked.apply(lambda x : x if x is not np.NaN else 'S')

# %%
df["Embarked"] .value_counts(dropna=False)
# Out:
# S    636
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# * 나이에 대한 빠진 값을 --> SibSp / Parch / Pclass의 값이 같으면 그 데이터들을 모아서 중간값으로 예측, 아니면 나이 데이터 중에서 단순 중간값으로 채우기!!

# %%
index_NaN_age = list(df["Age"][df["Age"].isnull()].index)

age_idx = df.columns.get_loc("Age")
SibSp_idx = df.columns.get_loc("SibSp")
Parch_idx = df.columns.get_loc("Parch")
Pclass_idx = df.columns.get_loc("Pclass")

for i in index_NaN_age :
    age_med = df["Age"].median()
    age_pred = df["Age"][((df['SibSp'] == df.iloc[i]["SibSp"]) 
                             & (df['Parch'] == df.iloc[i]["Parch"]) & 
                             (df['Pclass'] == df.iloc[i]["Pclass"]))].median()
    if not np.isnan(age_pred) :
        df.iat[i, age_idx] = age_pred
    else :
        df.iat[i, age_idx]  = age_med

# %% [markdown]
# ### 문제3_3) 아래와 같이 Cabin의 컬럼에 대해서 빠진 680데이터에는  "X"라는 문자열의 값으로 채우고, 맨 앞의 1글자만으로 객실을 단순화 하세요!!! (아래 결과표 참고)

# %%
df["Cabin"] .value_counts(dropna=False)
# Out:
# NaN        680
# B96 B98      4
# G6           4
# F2           3
# F33          3
#           ...
# D28          1
# B50          1
# B78          1
# E36          1
# D45          1
# Name: Cabin, Length: 148, dtype: int64

# %%
####### 수정한 코드

df.Cabin = df.Cabin.apply(lambda x : str(x)[0] if x is not np.NaN else 'X')

df["Cabin"].value_counts(dropna=False)
# Out:
# X    680
# C     56
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %% [markdown]
# * 전체적으로 우선은 빠진 데이터가 없는지 확인!!

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# * 기본적인 일괄적인 전처리 예정
#  - 수행 1 : "PassengerId", "Name", "Ticket" 컬럼 삭제
#  - 수행 2: "Cabin", "Sex", "Embarked" 컬럼 인코더 수행

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#
def drop_feature(df):
    df.drop(["PassengerId", "Name", "Ticket"], axis=1, inplace=True)
    return df

# %%
def format_features(df):
    # 변경할 컬럼 리스트    
    features = ["Cabin", "Sex", "Embarked"]
    for feature in features:
        # 각기 컬럼별로 수행할 인코더 설정 -> 컬럼 별로 다르게 되니 매 for 마다 새로운 것이 불러올 것!!
        le = preprocessing.LabelEncoder()
        # 인코딩할 컬럼 설절 및 그에 맞는 학습 수행 -> fit
        le = le.fit(df.loc[:,feature])
        # 실제 학습한 내용을 적용!!!! -> transform
        df.loc[:, feature] = le.transform(df.loc[:, feature])
    
    
    # Scalar  사용할 수 있음!!!!

    return df

# %%
def titanic_transform(df):
    df = drop_feature(df)
    df = format_features(df)
    return df

# %%
X_titanic_train = titanic_transform(df)
X_titanic_train.head(3)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked
# 0         0       3    1  22.0      1      0   7.2500      8         2
# 1         1       1    0  38.0      1      0  71.2833      2         0
# 2         1       3    0  26.0      0      0   7.9250      8         2

# %%
y_titanic_train = X_titanic_train.iloc[:,0]
X_titanic_train =X_titanic_train.iloc[:,1:]

# %% [markdown]
# * 데이터 분리

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_titanic_train, 
                                                    y_titanic_train, 
                                                    stratify = y_titanic_train,
                                                    test_size=0.3, 
                                                    random_state=1234)

# %% [markdown]
# * 참고) 우리의 비교 모델!!! Random Forest의 정확도 0.81

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
rf_clf = RandomForestClassifier(n_jobs=-1, random_state=1234)
rf_clf.fit(X_train,y_train)

rfc_predictions = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test, rfc_predictions)
print("Random Forest 의 Test Accuracy Result  : {0: .4f}".format(accuracy))
# Out:
# Random Forest 의 Test Accuracy Result  :  0.8151

# %% [markdown]
# ### 문제3_4) 비교 모델 Random Forest의 정확도 0.815보다 높은 DNN 모델을 만들어서 타이타닉의 생존을 예측하는 분류 모델을 만드세요!!(DNN모델 이외의 제약 조건은 없음!!!!)

# %%
# Out:
# 265/1 - 0s - loss: 0.5296 - accuracy: 0.8302
# [0.39467792960832704, 0.8301887]

# %%
# Out:
# 265/1 - 0s - loss: 0.5289 - accuracy: 0.8264
# [0.41572618574466347, 0.8264151]

# %%
# Out:
# 265/1 - 1s - loss: 0.5478 - accuracy: 0.8377
# [0.41806211651496167, 0.83773583]

# %%
X_train_np = X_train.to_numpy
X_test_np = X_test.to_numpy

# %%
X_train_n = np.array([])

for idx in range(len(X_train)) :

    tmp = np.array([])
    
    for idx2 in range(len(X_train.iloc[idx,:])) :
        tmp = np.append(tmp,X_train.iat[idx,idx2])
    
    X_train_n = np.append(X_train_n, tmp)

X_train_n = X_train_n.reshape(X_train.shape)

X_train_tf = tf.constant(X_train_n)

# %%
X_test_n = np.array([])

for idx in range(len(X_test)) :

    tmp = np.array([])
    
    for idx2 in range(len(X_test.iloc[idx,:])) :
        tmp = np.append(tmp,X_test.iat[idx,idx2])
    
    X_test_n = np.append(X_test_n, tmp)
    
X_test_n = X_test_n.reshape(X_test.shape)

X_test_tf = tf.constant(X_test_n)

# %%
X_train_tf
# Out:
# <tf.Tensor: shape=(616, 8), dtype=float64, numpy=
# array([[ 2.    ,  0.    , 34.    , ..., 10.5   ,  5.    ,  2.    ],
#        [ 3.    ,  1.    , 36.    , ..., 15.55  ,  8.    ,  2.    ],
#        [ 2.    ,  0.    , 50.    , ..., 10.5   ,  8.    ,  2.    ],
#        ...,
#        [ 3.    ,  1.    , 14.    , ..., 39.6875,  8.    ,  2.    ],
#        [ 1.    ,  1.    , 55.    , ..., 30.5   ,  2.    ,  2.    ],
#        [ 1.    ,  0.    , 48.    , ..., 39.6   ,  0.    ,  0.    ]])>

# %%
#test_Y => one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
import os
# 파일 이름에 에포크 번호를 포함시킵니다(`str.format` 포맷)
checkpoint_path = "drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, verbose=1, save_weights_only=True)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=8, activation='relu', input_shape=(8,)),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=16, activation='elu'),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=16, activation='elu'),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=8, activation='relu'),

    tf.keras.layers.Dense(units=2, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Nadam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(X_train_tf, y_train, epochs=316, batch_size=20, validation_split=0.25, callbacks=[cp_callback])
model.evaluate(X_test_tf, y_test,verbose=0)
# Out:
# Train on 462 samples, validate on 154 samples
# Epoch 1/316
# 462/462 [==============================] - 1s 2ms/sample - loss: 0.7100 - accuracy: 0.6061 - val_loss: 0.7301 - val_accuracy: 0.5909
# Epoch 2/316
# 462/462 [==============================] - 0s 145us/sample - loss: 0.6410 - accuracy: 0.6645 - val_loss: 0.6470 - val_accuracy: 0.5714
# Epoch 3/316
# 462/462 [==============================] - 0s 143us/sample - loss: 0.6297 - accuracy: 0.6861 - val_loss: 0.6436 - val_accuracy: 0.5974
# Epoch 4/316
# 462/462 [==============================] - 0s 181us/sample - loss: 0.6182 - accuracy: 0.6970 - val_loss: 0.6728 - val_accuracy: 0.6039
# Epoch 5/316
# 462/462 [==============================] - 0s 146us/sample - loss: 0.6232 - accuracy: 0.6732 - val_loss: 0.6369 - val_accuracy: 0.6104
# Epoch 6/316
# 462/462 [==============================] - 0s 203us/sample - loss: 0.6146 - accuracy: 0.6797 - val_loss: 0.6473 - val_accuracy: 0.6234
# Epoch 7/316
# 462/462 [==============================] - 0s 156us/sample - loss: 0.6102 - accuracy: 0.6775 - val_loss: 0.6107 - val_accuracy: 0.6104
# Epoch 8/316
# 462/462 [==============================] - 0s 152us/sample - loss: 0.6086 - accuracy: 0.6688 - val_loss: 0.6191 - val_accuracy: 0.6299
# Epoch 9/316
# 462/462 [==============================] - 0s 143us/sample - loss: 0
saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0389.ckpt
# 462/462 [==============================] - 0s 320us/sample - loss: 0.5053 - accuracy: 0.7814 - val_loss: 0.5446 - val_accuracy: 0.7403
# Epoch 390/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.4275 - accuracy: 0.8000
# Epoch 00390: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0390.ckpt
# 462/462 [==============================] - 0s 263us/sample - loss: 0.5039 - accuracy: 0.7771 - val_loss: 0.5442 - val_accuracy: 0.7468
# Epoch 391/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.3463 - accuracy: 0.9500
# Epoch 00391: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0391.ckpt
# 462/462 [==============================] - 0s 303us/sample - loss: 0.5173 - accuracy: 0.7532 - val_loss: 0.5703 - val_accuracy: 0.7468
# Epoch 392/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.4975 - accuracy: 0.7500
# Epoch 00392: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0392.ckpt
# 462/462 [==============================] - 0s 279us/sample - loss: 0.5015 - accuracy: 0.7857 - val_loss: 0.5551 - val_accuracy: 0.7338
# Epoch 393/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.4020 - accuracy: 0.8500
# Epoch 00393: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0393.ckpt
# 462/462 [==============================] - 0s 311us/sample - loss: 0.4897 - accuracy: 0.7900 - val_loss: 0.5075 - val_accuracy: 0.7403
# Epoch 394/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.4790 - accuracy: 0.8000
# Epoch 00394: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0394.ckpt
# 462/462 [==============================] - 0s 273us/sample - loss: 0.4903 - accuracy: 0.7900 - val_loss: 0.5349 - val_accuracy: 0.7468
# Epoch 395/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.3941 - accuracy: 0.8000
# Epoch 00395: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0395.ckpt
# 462/462 [==============================] - 0s 266us/sample - loss: 0.4985 - accuracy: 0.7835 - val_loss: 0.5451 - val_accuracy: 0.7468
# Epoch 396/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.5701 - accuracy: 0.7500
# Epoch 00396: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0396.ckpt
# 462/462 [==============================] - 0s 334us/sample - loss: 0.4790 - accuracy: 0.7792 - val_loss: 0.5440 - val_accuracy: 0.7338
# Epoch 397/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.4242 - accuracy: 0.8500
# Epoch 00397: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0397.ckpt
# 462/462 [==============================] - 0s 286us/sample - loss: 0.5051 - accuracy: 0.7835 - val_loss: 0.5496 - val_accuracy: 0.7468
# Epoch 398/400
#  20/462 [>.............................] - ETA: 0s - loss: 0.3779 - accuracy: 0.9000
# Epoch 00398: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0398.ckpt
# 462/462 [==============================] - 0s 288us/sample - loss: 0.4811 - accuracy: 0.7987 - val_loss: 0.5812 - val_accuracy: 0.7273
# Epoch 399/400
# 440/462 [===========================>..] - ETA: 0s - loss: 0.4816 - accuracy: 0.7818
# Epoch 00399: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0399.ckpt
# 462/462 [==============================] - 0s 344us/sample - loss: 0.4864 - accuracy: 0.7814 - val_loss: 0.5309 - val_accuracy: 0.7468
# Epoch 400/400
# 280/462 [=================>............] - ETA: 0s - loss: 0.4370 - accuracy: 0.8286
# Epoch 00400: saving model to drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0400.ckpt
# 462/462 [==============================] - 0s 339us/sample - loss: 0.4875 - accuracy: 0.7987 - val_loss: 0.5284 - val_accuracy: 0.7468
# [0.44375120086489983, 0.8226415]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=8, activation='relu', input_shape=(8,)),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=16, activation='elu'),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=16, activation='elu'),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=16, activation='elu'),
    tf.keras.layers.Dropout(rate=0.1),
    tf.keras.layers.Dense(units=8, activation='relu'),

    tf.keras.layers.Dense(units=2, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Nadam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy'])


checkpoint_path_best = 'drive/My Drive/pythonWorkspace/checkpoint/test/cp_test-0398.ckpt'
model.load_weights(checkpoint_path_best)

model.evaluate(X_test_tf, y_test,verbose=0)
# Out:
# [0.43570502366659775, 0.8301887]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units
- val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 72us/sample - loss: 0.4199 - accuracy: 0.8126 - val_loss: 0.4749 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 71us/sample - loss: 0.4423 - accuracy: 0.8164 - val_loss: 0.4751 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 70us/sample - loss: 0.4330 - accuracy: 0.8031 - val_loss: 0.4665 - val_accuracy: 0.7527
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 67us/sample - loss: 0.4358 - accuracy: 0.7973 - val_loss: 0.4539 - val_accuracy: 0.7849
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 98us/sample - loss: 0.4192 - accuracy: 0.8298 - val_loss: 0.4593 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 69us/sample - loss: 0.4274 - accuracy: 0.8069 - val_loss: 0.4646 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 70us/sample - loss: 0.3942 - accuracy: 0.8298 - val_loss: 0.4603 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 64us/sample - loss: 0.4284 - accuracy: 0.8031 - val_loss: 0.4837 - val_accuracy: 0.7527
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 71us/sample - loss: 0.4354 - accuracy: 0.7973 - val_loss: 0.4699 - val_accuracy: 0.7634
# Train on 523 samples, validate on 93 samples
# 523/523 [==============================] - 0s 74us/sample - loss: 0.4333 - accuracy: 0.8088 - val_loss: 0.4652 - val_accuracy: 0.7742
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    4105     # without introducing a circular dependency.
# -> 4106     return params.sparse_read(indices, name=name)
#    4107   except AttributeError:
#
# AttributeError: 'Tensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-ea93961b613c> in <module>()
#       1 while(1):
# ----> 2     model.fit(X_train_tf, y_train, epochs=1, batch_size=64, validation_split=0.15)
#       3     if model.evaluate(X_test_tf, y_test,verbose=0)[1] > 0.842:
#       4         break
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     233           max_queue_size=max_queue_size,
#     234           workers=workers,
# --> 235           use_multiprocessing=use_multiprocessing)
#     236
#     237       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     575         sample_weight_modes=sample_weight_modes,
#     576         batch_size=batch_size,
# --> 577         distribution_strategy=distribution_strategy)
#     578   else:
#     579     train_adapter = _process_inputs(
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     355     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     356
# --> 357     dataset = self.slice_inputs(indices_dataset, inputs)
#     358
#     359     if shuffle == "batch":
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     388
#     389     dataset = dataset.map(
# --> 390         grab_batch, num_parallel_calls=dataset_ops.AUTOTUNE)
#     391
#     392     # Default optimizations are disabled to avoid the overhead of (unnecessary)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls)
#    1589     else:
#    1590       return ParallelMapDataset(
# -> 1591           self, map_func, num_parallel_calls, preserve_cardinality=True)
#    1592
#    1593   def flat_map(self, map_func):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    3924         self._transformation_name(),
#    3925         dataset=input_dataset,
# -> 3926         use_legacy_function=use_legacy_function)
#    3927     self._num_parallel_calls = ops.convert_to_tensor(
#    3928         num_parallel_calls, dtype=dtypes.int32, name="num_parallel_calls")
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3145       with tracking.resource_tracker_scope(resource_tracker):
#    3146         # TODO(b/141462134): Switch to using garbage collection.
# -> 3147         self._function = wrapper_fn._get_concrete_function_internal()
#    3148
#    3149         if add_to_graph:
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _get_concrete_function_internal(self, *args, **kwargs)
#    2393     """Bypasses error checking when getting a graph function."""
#    2394     graph_function = self._get_concrete_function_internal_garbage_collected(
# -> 2395         *args, **kwargs)
#    2396     # We're returning this concrete function to someone, and they may keep a
#    2397     # reference to the FuncGraph without keeping a reference to the
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2387       args, kwargs = None, None
#    2388     with self._lock:
# -> 2389       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2390     return graph_function
#    2391
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    2701
#    2702       self._function_cache.missed.add(call_context_key)
# -> 2703       graph_function = self._create_graph_function(args, kwargs)
#    2704       self._function_cache.primary[cache_key] = graph_function
#    2705       return graph_function, args, kwargs
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    2591             arg_names=arg_names,
#    2592             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 2593             capture_by_value=self._capture_by_value),
#    2594         self._function_attributes,
#    2595         # Tell the ConcreteFunction to clean up its graph once it goes out of
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     976                                           converted_func)
#     977
# --> 978       func_outputs = python_func(*func_args, **func_kwargs)
#     979
#     980       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in wrapper_fn(*args)
#    3138           attributes=defun_kwargs)
#    3139       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3140         ret = _wrapper_helper(*args)
#    3141         ret = structure.to_tensor_list(self._output_structure, ret)
#    3142         return [ops.convert_to_tensor(t) for t in ret]
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/data/ops/dataset_ops.py in _wrapper_helper(*args)
#    3080         nested_args = (nested_args,)
#    3081
# -> 3082       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3083       # If `func` returns a list of tensors, `nest.flatten()` and
#    3084       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     232           optional_features=optional_features)
#     233       try:
# --> 234         return converted_call(f, args, kwargs, options=options)
#     235       except Exception as e:  # pylint:disable=broad-except
#     236         if hasattr(e, 'ag_error_metadata'):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     457
#     458   if not options.user_requested and conversion.is_whitelisted_for_graph(f):
# --> 459     return _call_unconverted(f, args, kwargs, options)
#     460
#     461   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     328   try:
#     329     if kwargs is not None:
# --> 330       return f(*args, **kwargs)
#     331     else:
#     332       return f(*args)
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/data_adapter.py in grab_batch(i, data)
#     385
#     386     def grab_batch(i, data):
# --> 387       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     388
#     389     dataset = dataset.map(
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/nest.py in <listcomp>(.0)
#     566
#     567   return pack_sequence_as(
# --> 568       structure[0], [func(*x) for x in entries],
#     569       expand_composites=expand_composites)
#     570
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/keras/engine/data_adapter.py in <lambda>(d)
#     385
#     386     def grab_batch(i, data):
# --> 387       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     388
#     389     dataset = dataset.map(
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/array_ops.py in gather(***failed resolving arguments***)
#    4106     return params.sparse_read(indices, name=name)
#    4107   except AttributeError:
# -> 4108     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#    4109
#    4110
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/ops/gen_array_ops.py in gather_v2(params, indices, axis, batch_dims, name)
#    3688   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3689         "GatherV2", params=params, indices=indices, axis=axis,
# -> 3690                     batch_dims=batch_dims, name=name)
#    3691   _result = _outputs[:]
#    3692   if _execute.must_record_gradient():
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     740       op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     741                                  name=scope, input_types=input_types,
# --> 742                                  attrs=attr_protos, op_def=op_def)
#     743
#     744     # `outputs` is returned as a separate return value so that the output
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     593     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     594         op_type, inputs, dtypes, input_types, name, attrs, op_def,
# --> 595         compute_device)
#     596
#     597   def capture(self, tensor, name=None, shape=None):
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3320           input_types=input_types,
#    3321           original_op=self._default_original_op,
# -> 3322           op_def=op_def)
#    3323       self._create_op_helper(ret, compute_device=compute_device)
#    3324     return ret
#
# /tensorflow-2.1.0/python3.6/tensorflow_core/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1698
#    1699     if isinstance(node_def, node_def_pb2.NodeDef):
# -> 1700       if node_def.ByteSize() >= (1 << 31) or node_def.ByteSize() < 0:
#    1701         raise ValueError(
#    1702             "Cannot create a tensor proto whose content is larger than 2GB.")
#
# KeyboardInterrupt:

# %%
model.save_weights('drive/My Drive/pythonWorkspace/checkpoint/update/cp_003.ckpt')
model.evaluate(X_test_tf, y_test,verbose=0)
# Out:
# [0.4322823569459735, 0.84150946]
