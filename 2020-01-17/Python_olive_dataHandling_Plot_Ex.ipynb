# %% [markdown]
# # Olive Data

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# olive 파일 읽기
path = "C:/dev/pythonWorkspace/sampledata/01_olive.csv"

# %%
df=pd.read_csv(path)
df.head(5)
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
# 컬럼이름 변경하기 : 1번 컬럼
df.rename(?)
df.columns
# Out:
# Index(['areaID', 'region', 'area', 'palmitic', 'palmitoleic', 'stearic',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 0':'areaID'}, inplace=True)
df.columns
# Out:
# Index(['areaID', 'region', 'area', 'palmitic', 'palmitoleic', 'stearic',
#        'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic'],
#       dtype='object')

# %%
df.region # 컬럼을 들고 오는 방법이 이런 방법도 있다 확인해둘것
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 567    3
# 568    3
# 569    3
# 570    3
# 571    3
# Name: region, Length: 572, dtype: int64

# %%
# region과 area컬럼의 유니크한 값들 확인
print('regions\t', df.?.?())
print('areas\t', df.?.?())
# Out:
# regions	 [1 2 3]
# areas	 [1 2 3 4 5 6 9 7 8]

# %%
# region과 area컬럼의 유니크한 값들 확인
print('regions\t', df.loc[:,'region'].unique())
print('areas\t', df.loc[:,'area'].unique())
# Out:
# regions	 [1 2 3]
# areas	 [1 2 3 4 5 6 9 7 8]

# %% [markdown]
# # Try)area - region에 관한 crosstab생성하기

# %%
pd.crosstab(?)
# Out:
# region    1   2   3
# area
# 1        25   0   0
# 2        56   0   0
# 3       206   0   0
# 4        36   0   0
# 5         0  65   0
# 6         0  33   0
# 7         0   0  50
# 8         0   0  50
# 9         0   0  51

# %%
pd.crosstab(df.loc[:,'area'],df.loc[:,'region'])
# Out:
# region    1   2   3
# area
# 1        25   0   0
# 2        56   0   0
# 3       206   0   0
# 4        36   0   0
# 5         0  65   0
# 6         0  33   0
# 7         0   0  50
# 8         0   0  50
# 9         0   0  51

# %% [markdown]
# # Try)데이터 탐색 후 처음컬럼의 숫자 제거(apply - lambda)

# %%
df.head()
# Out:
#            areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df["areaID"]=???
df.head()
# Out:
#          areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  North-Apulia       1     1      1075           75      226   7823
# 1  North-Apulia       1     1      1088           73      224   7709
# 2  North-Apulia       1     1       911           54      246   8113
# 3  North-Apulia       1     1       966           57      240   7952
# 4  North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df["areaID"]=df['areaID'].apply(lambda x : x.split('.')[1])
df.head()
# Out:
#          areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  North-Apulia       1     1      1075           75      226   7823
# 1  North-Apulia       1     1      1088           73      224   7709
# 2  North-Apulia       1     1       911           54      246   8113
# 3  North-Apulia       1     1       966           57      240   7952
# 4  North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %% [markdown]
# # Try) areastring 컬럼의 유니크한 값 확인

# %%
df["areaID"].?()
# Out:
# array(['North-Apulia', 'Calabria', 'South-Apulia', 'Sicily',
#        'Inland-Sardinia', 'Coast-Sardinia', 'Umbria', 'East-Liguria',
#        'West-Liguria'], dtype=object)

# %%
df["areaID"].unique()
# Out:
# array(['North-Apulia', 'Calabria', 'South-Apulia', 'Sicily',
#        'Inland-Sardinia', 'Coast-Sardinia', 'Umbria', 'East-Liguria',
#        'West-Liguria'], dtype=object)

# %% [markdown]
# # Try) 산성관련 성분 :'palmitic', 'palmitoleic', 'stearic', 'oleic', 'linoleic', 'linolenic', 'arachidic', 'eicosenoic' 의 칼럼의 데이터만 추려서 subdf생성하기

# %%
?
dfsub = ?
dfsub.head()
# Out:
#    palmitic  palmitoleic  stearic  oleic  linoleic  linolenic  arachidic  \
# 0      1075           75      226   7823       672         36         60
# 1      1088           73      224   7709       781         31         61
# 2       911           54      246   8113       549         31         63
# 3       966           57      240   7952       619         50         78
# 4      1051           67      259   7771       672         50         80
#
#    eicosenoic
# 0          29
# 1          29
# 2          29
# 3          35
# 4          46

# %%
df.loc[:,'palmitic':'eicosenoic']
dfsub = df.loc[:,'palmitic':'eicosenoic']
dfsub.head()
# Out:
#    palmitic  palmitoleic  stearic  oleic  linoleic  linolenic  arachidic  \
# 0      1075           75      226   7823       672         36         60
# 1      1088           73      224   7709       781         31         61
# 2       911           54      246   8113       549         31         63
# 3       966           57      240   7952       619         50         78
# 4      1051           67      259   7771       672         50         80
#
#    eicosenoic
# 0          29
# 1          29
# 2          29
# 3          35
# 4          46

# %% [markdown]
# # Try) dfsub의 데이터를 모두 0.**인 소수로 나타내기 --> df sub의 모든 칼럼에 /100

# %%
# 앞의 데이터 생성과 lambda apply 동시에...
dfsub= dfsub.apply(lambda x : x/100)
dfsub.head()
# Out:
#    palmitic  palmitoleic  stearic  oleic  linoleic  linolenic  arachidic  \
# 0     10.75         0.75     2.26  78.23      6.72       0.36       0.60
# 1     10.88         0.73     2.24  77.09      7.81       0.31       0.61
# 2      9.11         0.54     2.46  81.13      5.49       0.31       0.63
# 3      9.66         0.57     2.40  79.52      6.19       0.50       0.78
# 4     10.51         0.67     2.59  77.71      6.72       0.50       0.80
#
#    eicosenoic
# 0        0.29
# 1        0.29
# 2        0.29
# 3        0.35
# 4        0.46

# %% [markdown]
# # Try) df에서 acidlist 의 컬럼의 데이터를 위에서 lambda apply로 /100으로 처리한 값들로 치환하기

# %%
df[?]=?
df.head()
# Out:
#          areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  North-Apulia       1     1     10.75         0.75     2.26  78.23
# 1  North-Apulia       1     1     10.88         0.73     2.24  77.09
# 2  North-Apulia       1     1      9.11         0.54     2.46  81.13
# 3  North-Apulia       1     1      9.66         0.57     2.40  79.52
# 4  North-Apulia       1     1     10.51         0.67     2.59  77.71
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0      6.72       0.36       0.60        0.29
# 1      7.81       0.31       0.61        0.29
# 2      5.49       0.31       0.63        0.29
# 3      6.19       0.50       0.78        0.35
# 4      6.72       0.50       0.80        0.46

# %%
df.loc[:,'palmitic':'eicosenoic'] = dfsub
df.head()
# Out:
#          areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  North-Apulia       1     1     10.75         0.75     2.26  78.23
# 1  North-Apulia       1     1     10.88         0.73     2.24  77.09
# 2  North-Apulia       1     1      9.11         0.54     2.46  81.13
# 3  North-Apulia       1     1      9.66         0.57     2.40  79.52
# 4  North-Apulia       1     1     10.51         0.67     2.59  77.71
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0      6.72       0.36       0.60        0.29
# 1      7.81       0.31       0.61        0.29
# 2      5.49       0.31       0.63        0.29
# 3      6.19       0.50       0.78        0.35
# 4      6.72       0.50       0.80        0.46

# %% [markdown]
# # 팔마트산/리놀렐라산의 분포도 그리기[ palmitic, linolenic]

# %%
fig=plt.figure()
plt.scatter(df["palmitic"], df["linolenic"])
axis = fig.gca() #get current axis
axis.set_title('linolenic vs palmitic')
axis.set_xlabel('palmitic')
axis.set_ylabel('linolenic')
# Out:
# Text(0,0.5,'linolenic')

# %%
fig=plt.figure()
plt.scatter(df["palmitic"], df["linolenic"])
axis = fig.gca() #get current axis
axis.set_title('linolenic vs palmitic')
axis.set_xlabel('palmitic')
axis.set_ylabel('linolenic')
# Out:
# Text(0, 0.5, 'linolenic')

# %% [markdown]
# # palmitic 히스토그램 간단히 그리기

# %%
plt.hist(df["palmitic"])
# Out:
# (array([  1.,   0.,  11.,  71., 188.,  79., 131.,  73.,   9.,   9.]),
#  array([ 6.1  ,  7.243,  8.386,  9.529, 10.672, 11.815, 12.958, 14.101,
#         15.244, 16.387, 17.53 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # 앞의 그래프들을 활용하여 비슷한 그래프들에 대한 종류를 비교

# %%
fig, axes=plt.subplots(figsize=(20,20), nrows=2, ncols=2)
axes[?][?].plot(df["palmitic"], df["linolenic"])
axes[?][?].plot(df["palmitic"], df["linolenic"], '.')
axes[?][?].scatter(df["palmitic"], df["linolenic"])
axes[?][?].hist(df["palmitic"])
fig.tight_layout()

# %%
fig, axes=plt.subplots(figsize=(20,20), nrows=2, ncols=2)
axes[0][0].plot(df["palmitic"], df["linolenic"])
axes[0][1].plot(df["palmitic"], df["linolenic"], '.')
axes[1][0].scatter(df["palmitic"], df["linolenic"])
axes[1][1].hist(df["palmitic"])
fig.tight_layout()

# %% [markdown]
# # Try) xacids=['oleic','linolenic','eicosenoic'], yacids=['stearic','arachidic'] 을 가지고 각기 xacids-yacids의 scatter plot를 그리기
# Tip) subplot에서 nrows = len(xacids), ncols = len(yacids)
# Tip) 위의 각기 컬럼들을 리스트로 가지고 있으니, for를 활용하여 6개의 그래프를 쉽게 생성하는 방법을 사용하자. 2중 for loop

# %%
xacids=['oleic','linolenic','eicosenoic']
yacids=['stearic','arachidic']

fig, axes=plt.subplots(figsize=(15,15), nrows=len(xacids), ncols=len(yacids))
for i, xacid in enumerate(xacids):
    for j, yacid in enumerate(yacids):
        axes[i][j].scatter(df[xacid],df[yacid])
        axes[i][j].set_xlabel(xacid)
        axes[i][j].set_ylabel(yacid)
fig.tight_layout()

# %% [markdown]
# # Try) groupby를 활용하여 region을 기준으로 묶어서 region_groupby객체로 생성
# Tip) region_groupby = df.groupby(~~~~)

# %%
region_groupby = df.groupby(?)
region_groupby
# key-value구조라서 바로 보이지 않음;;;

# %%
region_groupby = df.groupby('region')
region_groupby
# key-value구조라서 바로 보이지 않음;;;

for i,v in enumerate(region_groupby) :
    print('{} : {}'.format(i,v))
# Out:
# 0 : (1,            areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0    North-Apulia       1     1     10.75         0.75     2.26  78.23
# 1    North-Apulia       1     1     10.88         0.73     2.24  77.09
# 2    North-Apulia       1     1      9.11         0.54     2.46  81.13
# 3    North-Apulia       1     1      9.66         0.57     2.40  79.52
# 4    North-Apulia       1     1     10.51         0.67     2.59  77.71
# ..            ...     ...   ...       ...          ...      ...    ...
# 318  South-Apulia       1     3     16.38         2.52     2.15  65.70
# 319  South-Apulia       1     3     14.97         2.47     2.19  66.21
# 320  South-Apulia       1     3     14.42         2.22     1.94  66.77
# 321  South-Apulia       1     3     16.80         2.70     1.70  64.40
# 322  South-Apulia       1     3     14.63         1.64     1.85  69.09
#
#      linoleic  linolenic  arachidic  eicosenoic
# 0        6.72       0.36       0.60        0.29
# 1        7.81       0.31       0.61        0.29
# 2        5.49       0.31       0.63        0.29
# 3        6.19       0.50       0.78        0.35
# 4        6.72       0.50       0.80        0.46
# ..        ...        ...        ...         ...
# 318     11.99       0.39       0.53        0.29
# 319     12.70       0.36       0.73        0.32
# 320     13.14       0.36       0.72        0.38
# 321     13.10       0.31       0.62        0.28
# 322     11.54       0.49       0.58        0.17
#
# [323 rows x 11 columns])
# 1 : (2,               areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 323  Inland-Sardinia       2     5     11.29         1.20     2.22  72.72
# 324  Inland-Sardinia       2     5     10.42         1.35     2.10  73.76
# 325  Inland-Sardinia       2     5     11.03         0.96     2.10  73.80
# 326  Inland-Sardinia       2     5     11.18         0.97     2.21  72.79
# 327  Inland-Sardinia       2     5     10.52         0.95     2.15  73.88
# ..               ...     ...   ...       ...          ...      ...    ...
# 416   Coast-Sardinia       2     6     11.26         1.00     2.36  70.62
# 417   Coast-Sardinia       2     6     10.87         0.89     2.43  72.00
# 418   Coast-Sardinia       2     6     11.15         0.96     2.36  70.85
# 419   Coast-Sardinia       2     6     11.78         0.92     2.41  70.06
# 420   Coast-Sardinia       2     6     11.62         1.06     2.42  70.25
#
#      linoleic  linolenic  arachidic  eicosenoic
# 323     11.12       0.43       0.98        0.02
# 324     11.16       0.35       0.90        0.03
# 325     10.85       0.32       0.94        0.03
# 326     11.54       0.35       0.94        0.02
# 327     11.26       0.31       0.92        0.01
# ..        ...        ...        ...         ...
# 416     13.80       0.26       0.69        0.01
# 417     13.02       0.18       0.60        0.01
# 418     13.72       0.20       0.75        0.02
# 419     13.76       0.22       0.84        0.01
# 420     13.68       0.25       0.71        0.02
#
# [98 rows x 11 columns])
# 2 : (3,            areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 421        Umbria       3     9     10.85         0.70     1.80  79.55
# 422        Umbria       3     9     10.85         0.70     1.85  79.55
# 423        Umbria       3     9     10.90         0.60     1.90  79.50
# 424        Umbria       3     9     10.80         0.65     1.89  79.60
# 425        Umbria       3     9     10.90         0.60     1.95  79.55
# ..            ...     ...   ...       ...          ...      ...    ...
# 567  West-Liguria       3     8     12.80         1.10     2.90  74.90
# 568  West-Liguria       3     8     10.60         1.00     2.70  77.40
# 569  West-Liguria       3     8     10.10         0.90     2.10  77.20
# 570  West-Liguria       3     8      9.90         1.20     2.50  77.50
# 571  West-Liguria       3     8      9.60         0.80     2.40  79.50
#
#      linoleic  linolenic  arachidic  eicosenoic
# 421      6.05       0.20       0.50        0.01
# 422      6.00       0.25       0.55        0.01
# 423      6.00       0.28       0.47        0.02
# 424      6.02       0.35       0.20        0.01
# 425      6.00       0.28       0.42        0.02
# ..        ...        ...        ...         ...
# 567      7.90       0.10       0.10        0.02
# 568      8.10       0.10       0.10        0.03
# 569      9.70       0.00       0.00        0.02
# 570      8.70       0.10       0.10        0.02
# 571      7.40       0.10       0.20        0.02
#
# [151 rows x 11 columns])

# %%
region_groupby.head()
# Out:
#               areaID  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0       North-Apulia       1     1     10.75         0.75     2.26  78.23
# 1       North-Apulia       1     1     10.88         0.73     2.24  77.09
# 2       North-Apulia       1     1      9.11         0.54     2.46  81.13
# 3       North-Apulia       1     1      9.66         0.57     2.40  79.52
# 4       North-Apulia       1     1     10.51         0.67     2.59  77.71
# 323  Inland-Sardinia       2     5     11.29         1.20     2.22  72.72
# 324  Inland-Sardinia       2     5     10.42         1.35     2.10  73.76
# 325  Inland-Sardinia       2     5     11.03         0.96     2.10  73.80
# 326  Inland-Sardinia       2     5     11.18         0.97     2.21  72.79
# 327  Inland-Sardinia       2     5     10.52         0.95     2.15  73.88
# 421           Umbria       3     9     10.85         0.70     1.80  79.55
# 422           Umbria       3     9     10.85         0.70     1.85  79.55
# 423           Umbria       3     9     10.90         0.60     1.90  79.50
# 424           Umbria       3     9     10.80         0.65     1.89  79.60
# 425           Umbria       3     9     10.90         0.60     1.95  79.55
#
#      linoleic  linolenic  arachidic  eicosenoic
# 0        6.72       0.36       0.60        0.29
# 1        7.81       0.31       0.61        0.29
# 2        5.49       0.31       0.63        0.29
# 3        6.19       0.50       0.78        0.35
# 4        6.72       0.50       0.80        0.46
# 323     11.12       0.43       0.98        0.02
# 324     11.16       0.35       0.90        0.03
# 325     10.85       0.32       0.94        0.03
# 326     11.54       0.35       0.94        0.02
# 327     11.26       0.31       0.92        0.01
# 421      6.05       0.20       0.50        0.01
# 422      6.00       0.25       0.55        0.01
# 423      6.00       0.28       0.47        0.02
# 424      6.02       0.35       0.20        0.01
# 425      6.00       0.28       0.42        0.02

# %% [markdown]
# # region_groupby 에 describe() 메소드 적용

# %%
dfrd=region_groupby.describe()
dfrd.head(20)
# Out:
#        arachidic                                                      area  \
#            count      mean       std   min   25%   50%    75%   max  count
# region
# 1          323.0  0.631176  0.111644  0.32  0.56  0.62  0.690  1.02  323.0
# 2           98.0  0.731735  0.118826  0.45  0.66  0.72  0.810  1.05   98.0
# 3          151.0  0.375762  0.293586  0.00  0.10  0.38  0.595  1.00  151.0
#
#                   ...  palmitoleic       stearic                            \
#             mean  ...          75%   max   count      mean       std   min
# region            ...
# 1       2.783282  ...         1.85  2.80   323.0  2.287740  0.398709  1.52
# 2       5.336735  ...         1.04  1.35    98.0  2.261837  0.176363  1.99
# 3       8.006623  ...         1.00  1.80   151.0  2.308013  0.389560  1.70
#
#
#           25%   50%    75%   max
# region
# 1       2.015  2.23  2.495  3.75
# 2       2.120  2.22  2.395  2.72
# 3       2.000  2.30  2.500  3.50
#
# [3 rows x 72 columns]

# %% [markdown]
# # region_groupby에 mean, std 등 기타 메소드 적용

# %%
region_groupby.?()
# Out:
#             area   palmitic  palmitoleic   stearic      oleic   linoleic  \
# region
# 1       2.783282  13.322879     1.548019  2.287740  71.000093  10.334985
# 2       5.336735  11.113469     0.967449  2.261837  72.680204  11.965306
# 3       8.006623  10.948013     0.837351  2.308013  77.930530   7.270331
#
#         linolenic  arachidic  eicosenoic
# region
# 1        0.380650   0.631176    0.273220
# 2        0.270918   0.731735    0.019388
# 3        0.217881   0.375762    0.019735

# %%
region_groupby.mean() # 걍 때려박아야됨, 이미 region에 대해서 그룹이 되어있는 상태니까 걍 평균 찍으면된다리
# Out:
#             area   palmitic  palmitoleic   stearic      oleic   linoleic  \
# region
# 1       2.783282  13.322879     1.548019  2.287740  71.000093  10.334985
# 2       5.336735  11.113469     0.967449  2.261837  72.680204  11.965306
# 3       8.006623  10.948013     0.837351  2.308013  77.930530   7.270331
#
#         linolenic  arachidic  eicosenoic
# region
# 1        0.380650   0.631176    0.273220
# 2        0.270918   0.731735    0.019388
# 3        0.217881   0.375762    0.019735

# %%
region_groupby.apply(lambda x: x.mean())
# 참고)키-벨류에 의해서..위와 달리 region이 다시 컬럼에 있음.
# Out:
#         region      area   palmitic  palmitoleic   stearic      oleic  \
# region
# 1          1.0  2.783282  13.322879     1.548019  2.287740  71.000093
# 2          2.0  5.336735  11.113469     0.967449  2.261837  72.680204
# 3          3.0  8.006623  10.948013     0.837351  2.308013  77.930530
#
#          linoleic  linolenic  arachidic  eicosenoic
# region
# 1       10.334985   0.380650   0.631176    0.273220
# 2       11.965306   0.270918   0.731735    0.019388
# 3        7.270331   0.217881   0.375762    0.019735

# %%
region_groupby.std()
# Out:
#             area  palmitic  palmitoleic   stearic     oleic  linoleic  \
# region
# 1       0.741054  1.529349     0.507237  0.398709  3.451431  2.106730
# 2       0.475023  0.404111     0.138514  0.176363  1.418783  1.072336
# 3       0.820542  0.825635     0.264388  0.389560  1.648155  1.431226
#
#         linolenic  arachidic  eicosenoic
# region
# 1        0.079727   0.111644    0.083915
# 2        0.053844   0.118826    0.007436
# 3        0.168865   0.293586    0.007298

# %% [markdown]
# # region 1/2/3에 해당하는 값이 - 'South','Sardinia','North'이니, 이에 대한 맵핑된 dict가 필요함

# %%
rkeys=[1,2,3]
rvals=['South','Sardinia','North']
rmap={e[0]:e[1] for e in zip(rkeys,rvals)} # 
rmap
# Out:
# {1: 'South', 2: 'Sardinia', 3: 'North'}

# %% [markdown]
# # Try) region으로 groupby하고 나서, mean을 구하기
# # 단, 전체 컬럼이 아니라 acidlist 에 해당하는 컬럼만 추릴것.

# %%
mdf2=df.groupby('region').mean()
mdf2=mdf2[acidlist]
mdf2.head()
# Out:
#          palmitic  palmitoleic   stearic      oleic   linoleic  linolenic  \
# region
# 1       13.322879     1.548019  2.287740  71.000093  10.334985   0.380650
# 2       11.113469     0.967449  2.261837  72.680204  11.965306   0.270918
# 3       10.948013     0.837351  2.308013  77.930530   7.270331   0.217881
#
#         arachidic  eicosenoic
# region
# 1        0.631176    0.273220
# 2        0.731735    0.019388
# 3        0.375762    0.019735

# %% [markdown]
# # Try) barh 그래프 그리기

# %%
ax=mdf2.plot(kind='barh', stacked=True)
ax.set_yticklabels(rvals)
ax.set_xlim([0,100])
# Out:
# (0, 100)

# %% [markdown]
# # region별로 linoleic - arachidic scatter그래프

# %%
def regionSca(df, scatterx, scattery, by="region", labeler={}):
    figure=plt.figure(figsize=(8,8))
    ax=plt.gca()
    cs=list(np.linspace(0,1,len(df.groupby(by))))
    xlimsd={}
    ylimsd={}
    xs={}
    ys={}
    cold={}
    # 단 이것은 region이 3가지로 구분되어 있어서 임...
    c=["red","blue","green"]
    for k,g in df.groupby(by):
        col=cs.pop()
        x=g[scatterx]
        y=g[scattery]
        xs[k]=x
        ys[k]=y
        cold[k]=c
        ax.scatter(x, y, c=c[k-1],label=labeler.get(k,k), s=40, alpha=0.4);
        xlimsd[k]=ax.get_xlim()
        ylimsd[k]=ax.get_ylim()
    xlims=[min([xlimsd[k][0] for k in xlimsd.keys()]), max([xlimsd[k][1] for k in xlimsd.keys()])]
    ylims=[min([ylimsd[k][0] for k in ylimsd.keys()]), max([ylimsd[k][1] for k in ylimsd.keys()])]
    ax.set_xlim(xlims)
    ax.set_ylim(ylims)
    ax.set_xlabel(scatterx)
    ax.set_ylabel(scattery)
    ax.grid(False)
    return ax

# %%
a=regionSca(df, "linoleic","arachidic", labeler=rmap)
a.legend(loc='upper right');
