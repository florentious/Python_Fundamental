# %% [markdown]
# ###  Titanic_train.csv 파일을 data라는 변수에 불러오고, PassengerId를 index로 지정을 하시오!!!
# 필요한 패키지는 numpy / pandas / matplolib.pyplot

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pylab as plt

# %%
data = pd.read_csv('C:/dev/pythonWorkspace/2020-01-22/titanic_train.csv')

# %%
data = data.set_index('PassengerId')

# %%
#data = pd.read_csv('C:/dev/pythonWorkspace/2020-01-22/titanic_train.csv', index_col='PassengerId')

# %%
data.shape
# Out:
# (891, 11)

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# * 받은 데이터의 간략적인 정보 확인하세요!!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>714.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#       <td>891.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.383838</td>
#       <td>2.308642</td>
#       <td>29.699118</td>
#       <td>0.523008</td>
#       <td>0.381594</td>
#       <td>32.204208</td>
#     </tr>
#     <tr>
#       <th>std</th>
# ...

# %% [markdown]
# * 데이터들에서 NaN이 없는지 확인!!!

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.info() #간단히 볼수 있는거
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# * 항목별로 이상한 데이터들의 비율을 계산하시오!!!

# %%
# Out:
# Survived 0.0 %
# Pclass 0.0 %
# Name 0.0 %
# Sex 0.0 %
# Age 0.19865319865319866 %
# SibSp 0.0 %
# Parch 0.0 %
# Ticket 0.0 %
# Fare 0.0 %
# Cabin 0.7710437710437711 %
# Embarked 0.002244668911335578 %

# %%
for col in data.columns : 
    print(str(col), data[col].isnull().sum()*100/data.shape[0],'%') # 전체 rows 수로 나눠버리고 퍼센트 연산
# Out:
# Survived 0.0 %
# Pclass 0.0 %
# Name 0.0 %
# Sex 0.0 %
# Age 19.865319865319865 %
# SibSp 0.0 %
# Parch 0.0 %
# Ticket 0.0 %
# Fare 0.0 %
# Cabin 77.10437710437711 %
# Embarked 0.2244668911335578 %

# %% [markdown]
# ### 참고 : 데이터 항목 설명[ surveved : 생존여부(0/1), Pclass : 티켓의 클래스(1은 1st, 2는 2nd ..), name : 승객이름, sex : 승객성별, Age : 승객나이, SibSp : 함께 탑승한 형재와 배우자의 수, parch : 함께 탑승한 부모, 아이의 수, ticket: 티켓번호, Fare: 탑승료, cabin : 객실번호, embarked :탑승항구(C:Cherboug, Q :Queenstown, S:south ampton)]

# %% [markdown]
# * 탑승항구가 Cherboug 이면서, 탑승료를 200 초과로 지불한 사람들에 대한 데이터를 추리고, head로 앞에 불러서 확인!

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>119</th>
#       <td>0</td>
#       <td>1</td>
# ...

# %%
# data[data.Embarked == 'C'][data.Fare >= 200]
data[(data.Embarked == 'C')& (data.Fare >= 200)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
# 381                 1       1
# 558                 0       1
# 680                 1       1
# 701                 1       1
# 717                 1       1
# 738                 1       1
# 743                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 119                                   Baxter, Mr. Quigg Edmond    male  24.0
# 259                                           Ward, Miss. Anna  female  35.0
# 300            Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                                 Ryerson, Miss. Emily Borie  female  18.0
# 378                                  Widener, Mr. Harry Elkins    male  27.0
# ...

# %% [markdown]
# * 위의 조건에(항구/요금) 해당하는 것들을 요금에 대한 기준으로 정리를 하세요(요금이 높은 사람부터 낮은 사람 순서대로.)

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>259</th>
#       <td>1</td>
#       <td>1</td>
# ...

# %%
data[(data.Embarked == 'C')& (data.Fare >= 200)].sort_values(by='Fare', ascending=False)
# Out:
#              Survived  Pclass  \
# PassengerId
# 259                 1       1
# 680                 1       1
# 738                 1       1
# 312                 1       1
# 743                 1       1
# 119                 0       1
# 300                 1       1
# 381                 1       1
# 558                 0       1
# 701                 1       1
# 717                 1       1
# 378                 0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 259                                           Ward, Miss. Anna  female  35.0
# 680                         Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 738                                     Lesurer, Mr. Gustave J    male  35.0
# 312                                 Ryerson, Miss. Emily Borie  female  18.0
# 743                      Ryerson, Miss. Susan Parker "Suzette"  female  21.0
# ...

# %% [markdown]
# * 나이에 대항 카테고리를 정리하는 함수를 만들고(기준은 30미만은 1, 30이상~55미만은 2, 그 이상은 3으로 코딩)하는 함수 만들기.

# %%
data['AgeCat'] = data['Age'].apply(lambda x : 1 if x < 30 else (2 if x< 55 else 3) )

# %%
data[['Age','AgeCat']]
# Out:
#               Age  AgeCat
# PassengerId
# 1            22.0       1
# 2            38.0       2
# 3            26.0       1
# 4            35.0       2
# 5            35.0       2
# ...           ...     ...
# 887          27.0       1
# 888          19.0       1
# 889           NaN       3
# 890          26.0       1
# 891          32.0       2
#
# [891 rows x 2 columns]

# %%
def catAge(x) :
    if x < 30 :
        return(1)
    elif x < 55 :
        return(2)
    else :
        return(3)

# %% [markdown]
# * 위의 나이를 분류하는 함수를 바탕으로 Age_catogory하는 컬럼을 만들어서 생성하시오!!!

# %%
data['AgeCatCF'] = data['Age'].apply(lambda x : catAge(x))

# %%
data[['AgeCat','AgeCatCF']]
# Out:
#              AgeCat  AgeCatCF
# PassengerId
# 1                 1         1
# 2                 2         2
# 3                 1         1
# 4                 2         2
# 5                 2         2
# ...             ...       ...
# 887               1         1
# 888               1         1
# 889               3         3
# 890               1         1
# 891               2         2
#
# [891 rows x 2 columns]

# %%
(data['AgeCat'] == data['AgeCatCF']).value_counts()
# Out:
# True    891
# dtype: int64

# %%
data[data['AgeCat'] == None]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# * 성별이 남성, 성별이 여성인 사람들의 각각 전체 수는?

# %%
# Out:
# (577, 314)

# %%
(data['Sex']=='male').sum(), (data['Sex']=='female').sum()
# Out:
# (577, 314)

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# * 성별에 대해서 남성/여성이 어떻게 분포하는지 확인

# %%
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data['Sex'].value_counts().plot(kind='bar', title='Death and Survival Counts', color=['b','r'])

# %% [markdown]
# * 선실 등급 별로 성별이 어떻게 분포하는지 확인

# %%
data.groupby('Pclass').count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Sex, dtype: int64

# %%
pd.pivot_table(data, index='Pclass', columns='Sex', aggfunc='count',values='Survived', margins =True)
# Out:
# Sex     female  male  All
# Pclass
# 1           94   122  216
# 2           76   108  184
# 3          144   347  491
# All        314   577  891

# %% [markdown]
# * crosstab 에서도 아래와 같이 꾸밀 수 있음!!

# %%
# Out:
# <style  type="text/css" >
#     #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col0 {
#             background-color:  #ecf666;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col1 {
#             background-color:  #f8fc66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col0 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col1 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row1_col2 {
#             background-color:  #ffff66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col0 {
#             background-color:  #b6db66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col1 {
#             background-color:  #7dbe66;
#         }    #T_48f7a610_d332_11e8_80f2_ea8d2b9c0ca2row2_col2 {
#             background-color:  #90c866;
# ...

# %%
pd.crosstab(data.Pclass,data.Sex, margins=True)
# Out:
# Sex     female  male  All
# Pclass
# 1           94   122  216
# 2           76   108  184
# 3          144   347  491
# All        314   577  891

# %% [markdown]
# * 아래 그림과 같이 Pclass에 대한 히스토그램을 그리는데, 남자/여자/전체에 대해서 나타날 수 있도록 그리시오.

# %%
data['Pclass'].hist(label='all')
data[data['Sex']=='male']['Pclass'].hist(color='green',label='male')
data[data['Sex']=='female']['Pclass'].hist(color='yellow',label='female')

plt.title('Distribution by class and gender')
plt.legend(loc='upper left')
# plt.legend(loc=2)
plt.xlabel('Pclass')
plt.ylabel('Frequency')

# 전체를 그리고 하나씩 덧씌우는 작업
# Out:
# Text(0, 0.5, 'Frequency')

# %%
pd.crosstab(data.Pclass,data.Sex, margins=True).plot(kind='bar',stacked=True)

# %% [markdown]
# * 요금(fare)에 대한 평균/ 중앙값(median)/표준편차를 구해보시오.

# %%
# Out:
# Median fare:  14.45
# Fare std:  49.69

# %%
print('Mean fare: %.2f'%data.Fare.mean())
print('Median fare: %.2f'%data.Fare.median())
print('Fare Std: %.2f'%data.Fare.std())
# Out:
# Mean fare: 32.20
# Median fare: 14.45
# Fare Std: 49.69

# %%
round(12345.6754654,3) # 반올림함수 round(data, )
# Out:
# 12345.675

# %%
print('Mean fare: {}'.format(round(data.Fare.mean(),2)))
print('Median fare: {}'.format(round(data.Fare.median(),2)))
print('Std fare: {}'.format(round(data.Fare.std(),2)))
# Out:
# Mean fare: 32.2
# Median fare: 14.45
# Std fare: 49.69

# %% [markdown]
# * 아래 그래프와 같이 생존 여부에 대한 나이별로 그래프를 나타내보시오!

# %%
plt.hist(data[data['Survived']==1]['Age'],alpha=0.5,color='green',density=True)
plt.hist(data[data['Survived']==0]['Age'],alpha=0.5,color='red',density=True)
plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
data[data['Survived']==1]['Age'].hist(color='green',label='Survived',alpha=0.5,density=True)
data[data['Survived']==0]['Age'].hist(color='red',label='Died',alpha=0.5,density=True)

plt.grid(True)
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend()

# %% [markdown]
# * seaborn 패키지를 로드하세요.

# %%
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# * 아래 그림과 같이 생존 여부에 대한 나이별로 boxplot를 그려보세요.

# %%
sns.boxplot(x='Survived', y='Age', data=data)

# %% [markdown]
# * 생존자한 사람들의 나이 평균, 생존하지 못한 사람들의 나이 평균을 구하세요.

# %%
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
data.groupby('Survived')['Age'].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %% [markdown]
# * 위의 결과들을 보고, 본인만의 기준을 가지고 (젊은 생존자의 구분 : 예 30, 나이든 생존자의 구분: 예60)이런 식으로 구분을 하고, 각기 전체에서 얼마나 차지하는지 비율을 계산해보세요..

# %%
# Out:
# 젊은 생존자 : 40.6
# 고령 생존자 : 22.7

# %%
for i in range(1,4) :
    print( 'AgeCat '+str(i)+' : %.1f'%(data[data['AgeCat']==i]['Survived'].count()*100/data.shape[0]))
# Out:
# AgeCat 1 : 43.1
# AgeCat 2 : 32.3
# AgeCat 3 : 24.6

# %% [markdown]
# * 남성 중에서 생존자들과, 여성 중에서 생존자들에 대한 것을 가지고 각기 평균 비율을 구하시오.

# %%
# Out:
# 남성 생존자 :  18.9
# 여성 생존자 :  74.2

# %%
maleSurv = data[data['Sex']=='male']['Survived']
print('Male Survived : %.1f'%(maleSurv.value_counts()[1]*100/maleSurv.count()) )
femaleSurv = data[data['Sex']=='female']['Survived']
print('Female Survived : %.1f'%(femaleSurv.value_counts()[1]*100/femaleSurv.count()) )
# Out:
# Male Survived : 18.9
# Female Survived : 74.2

# %% [markdown]
# * 이름 컬럼에 대한 head()를 보이세요.

# %%
# Out:
# PassengerId
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
data.Name.head()
# Out:
# PassengerId
# 1                              Braund, Mr. Owen Harris
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                               Heikkinen, Miss. Laina
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
data.Name
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                         Graham, Miss. Margaret Edith
# 889             Johnston, Miss. Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# * 1번 사람의 이름을 , 를 구분하여 분리해서,.  first name만 나타내보세요.

# %%
# Out:
# 'Owen'

# %%
data['Name'][1].split(',')[1].split('.')[1].strip().split(' ')[0]
# Out:
# 'Owen'

# %%
data.loc[1,'Name'].split(',')[1].split()[1]
# Out:
# 'Owen'

# %%
data['first_names'] = data['Name'].apply(lambda x : x.split(',')[1].split('.')[1].strip().split(' ')[0])

# %%
first_names = data.loc[data['Sex']=='male','Name'].apply(lambda x : x.split(',')[1].split()[1])

first_names.value_counts().head()
# Out:
# William    35
# John       25
# George     14
# Thomas     13
# Charles    13
# Name: Name, dtype: int64

# %%
data['first_names']
# Out:
# PassengerId
# 1           Owen
# 2           John
# 3          Laina
# 4        Jacques
# 5        William
#          ...
# 887       Juozas
# 888     Margaret
# 889    Catherine
# 890         Karl
# 891      Patrick
# Name: first_names, Length: 891, dtype: object

# %% [markdown]
# * first_names 라는 변수를 만들어서 성별이 남자인 사람들의 firstname을 구하고, 각기  firstname별로 얼마나 많이 나타나는지 확인하세요.

# %%
# Out:
# William    35
# John       25
# George     14
# Thomas     13
# Charles    13
# Name: Name, dtype: int64

# %%
data[data.Sex == 'male']['first_names'].value_counts()
# Out:
# William     35
# John        25
# George      14
# Thomas      13
# Charles     13
#             ..
# Jean         1
# Ilmari       1
# Orsen        1
# Algernon     1
# Alfons       1
# Name: first_names, Length: 287, dtype: int64

# %%
data[data.Sex == 'male']['first_names'].value_counts().head()
# Out:
# William    35
# John       25
# George     14
# Thomas     13
# Charles    13
# Name: first_names, dtype: int64

# %% [markdown]
# * 각 등급별로 남성/여성의 평균 나이를 계산해서 나타내시오..

# %%
# Out:
# 평균나이 : male // 객실등급 3: 26.51
# 평균나이 : female // 객실등급 3: 21.75
# 평균나이 : male // 객실등급 1: 41.28
# 평균나이 : female // 객실등급 1: 34.61
# 평균나이 : male // 객실등급 2: 30.74
# 평균나이 : female // 객실등급 2: 28.72

# %%
# Out:
# 평균 나이 :female // 등급 : 1: 34.61
# 평균 나이 :male // 등급 : 1: 41.28
# 평균 나이 :female // 등급 : 2: 28.72
# 평균 나이 :male // 등급 : 2: 30.74
# 평균 나이 :female // 등급 : 3: 21.75
# 평균 나이 :male // 등급 : 3: 26.51

# %%
for i in data.Pclass.unique() :
    for sex in data.Sex.unique() :
        print('평균나이 :{}'.format(sex)+'// 등급 :',i,':',round(data[(data['Sex'] == sex) & (data['Pclass'] == i)]['Age'].mean(),2))
# Out:
# 평균나이 :male// 등급 : 3 : 26.51
# 평균나이 :female// 등급 : 3 : 21.75
# 평균나이 :male// 등급 : 1 : 41.28
# 평균나이 :female// 등급 : 1 : 34.61
# 평균나이 :male// 등급 : 2 : 30.74
# 평균나이 :female// 등급 : 2 : 28.72

# %%
round(data[(data['Sex'] == 'female') & (data['Pclass'] == 1)]['Age'].mean())
# Out:
# 34.61176470588235

# %%
for i in range(1,4) :
    idx = 0
    for sex in ['female','male'] :
        print('평균나이 :{}'.format(sex)+'// 등급 :',i,':',round(data.groupby(['Pclass','Sex'])['Age'].mean()[i][idx],2))
        idx += 1
# Out:
# 평균나이 :female// 등급 : 1 : 34.61
# 평균나이 :male// 등급 : 1 : 41.28
# 평균나이 :female// 등급 : 2 : 28.72
# 평균나이 :male// 등급 : 2 : 30.74
# 평균나이 :female// 등급 : 3 : 21.75
# 평균나이 :male// 등급 : 3 : 26.51

# %%
for (cl, sex), sub_df in data.groupby(['Pclass','Sex']) : #groupby 로 된걸 for문돌리기
    print('평균나이 :{0}// 등급 :{1}:{2}'.format(sex,cl,round(sub_df['Age'].mean(),2)))
# Out:
# 평균나이 :female// 등급 :1:34.61
# 평균나이 :male// 등급 :1:41.28
# 평균나이 :female// 등급 :2:28.72
# 평균나이 :male// 등급 :2:30.74
# 평균나이 :female// 등급 :3:21.75
# 평균나이 :male// 등급 :3:26.51

# %%
data.groupby(['Pclass','Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
data.groupby(['Pclass','Sex'])['Age'].mean()[1][0]
# Out:
# 34.61176470588235

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# * 등급별로 성별에 대한 나이 평균을 표로 만드세요.

# %%
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sex</th>
#       <th>female</th>
#       <th>male</th>
#     </tr>
#     <tr>
#       <th>Pclass</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>34.611765</td>
#       <td>41.281386</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28.722973</td>
#       <td>30.740707</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.750000</td>
#       <td>26.507589</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.pivot_table(data, index='Pclass', columns='Sex', aggfunc='mean',values='Age')
# Out:
# Sex        female       male
# Pclass
# 1       34.611765  41.281386
# 2       28.722973  30.740707
# 3       21.750000  26.507589

# %% [markdown]
# * 위의 그래프는 boxplot으로 나타내시오

# %%
sns.boxplot(data.Pclass, data.Age)

# %% [markdown]
# * 정보를 보면 cabin에 대해서는 정보가 많이 부족하기에, 이 항목은 제거.

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 1 to 891
# Data columns (total 10 columns):
# Survived    712 non-null int64
# Pclass      712 non-null int64
# Name        712 non-null object
# Sex         712 non-null object
# Age         712 non-null float64
# SibSp       712 non-null int64
# Parch       712 non-null int64
# Ticket      712 non-null object
# Fare        712 non-null float64
# Embarked    712 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 61.2+ KB

# %%
data.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  AgeCat  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S       1
# 2                1      0          PC 17599  71.2833   C85        C       2
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S       1
#
#              AgeCatCF first_names
# PassengerId
# 1                   1        Owen
# 2                   2        John
# 3                   1       Laina

# %%
data = data.drop(['Cabin'],axis=1)

# %%
data.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Embarked  AgeCat  AgeCatCF first_names
# PassengerId
# 1                0  A/5 21171  7.25        S       1         1        Owen

# %% [markdown]
# * survived/Age/Fare/SibSp/Parch에 대한 pairplot 그려보기

# %%
survived/Age/Fare/SibSp/Parch

# %%
sns.pairplot(data[['Survived','Age','Fare','SibSp','Parch']])
plt.show()

# %% [markdown]
# * Pclass, Fare에 대한 boxplot를 그려보시오!

# %%
sns.boxplot(data.Pclass, data.Fare)

# %% [markdown]
# * 위의 그래프를 보고, 원본 데이터에 대해서 이상한 아웃라이어를 제거하고 싶음. 그 기준은 0.95 인 quantile에 대한 값으로..수정을 해보자...

# %%
sns.boxplot(x='Pclass',y='Fare',data=data[data['Fare'] < data['Fare'].quantile(.95)])
# 이상치 상위 5퍼센트를 제거하고 집어 넣는거임
# 각각의 데이터 비례가 아니라 전체 data.Fare 의 상위5퍼만 날리고 받는거임

# %% [markdown]
# * Pclass별로 생존 여부 확인 --> 안 좋은 사실이 발견이 됨;;;ㅠㅠ

# %%
data[['Pclass','Survived']].groupby(['Pclass'],as_index = True).mean().sort_values(by='Survived',ascending=False).plot.bar()

# y축기준으로 하기위해서 sort_value='Survived'로 넣어줬음

# %%
# Out:
# Text(0.5,1,'Pclass:Survived vs Death')

# %%
fig, axes = plt.subplots(1,2,figsize=(10,5))

data['Pclass'].value_counts().plot.bar(color='red',ax=axes[0])
axes[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived',data=data,ax=axes[1])
axes[1].set_title('Pclass: Survived vs Death')
# ax 같은걸로 직접 위치 판단
# 2차원 분할인 경우 ax=axes[0,1]
# Out:
# Text(0.5, 1.0, 'Pclass: Survived vs Death')
